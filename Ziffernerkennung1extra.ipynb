# %%
import pickle
import os
Ordner_path='/content/drive/MyDrive/Variablen/'
file_pathw2=os.path.join(Ordner_path, 'w2.pkl')
file_pathb2=os.path.join(Ordner_path, 'b2.pkl')
file_pathw3=os.path.join(Ordner_path, 'w3.pkl')
file_pathb3=os.path.join(Ordner_path, 'b3.pkl')
file_pathw4=os.path.join(Ordner_path, 'w4.pkl')
file_pathb4=os.path.join(Ordner_path, 'b4.pkl')


with open(file_pathw2, 'wb') as f:
  pickle.dump(w2, f)
with open(file_pathb2, 'wb') as f:
  pickle.dump(b2, f)
with open(file_pathw3, 'wb') as f:
  pickle.dump(w3, f)
with open(file_pathb3, 'wb') as f:
  pickle.dump(b3, f)
with open(file_pathw4, 'wb') as f:
  pickle.dump(w4, f)
with open(file_pathb4, 'wb') as f:
  pickle.dump(b4, f)
print('gespeichert')
